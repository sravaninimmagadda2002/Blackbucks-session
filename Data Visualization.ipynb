# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2])
ypoints = np.array([5,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints = np.array([1,20])
ypoints = np.array([10,200])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints = np.array([1,20])
ypoints = np.array([10,200])
plt.plot(xpoints,ypoints,'+')
plt.show()

# %%
xpoints = np.array([1,20])
ypoints = np.array([10,200])
plt.plot(xpoints,ypoints,'*')
plt.show()

# %%
xpoints = np.array([1,20])
ypoints = np.array([10,200])
plt.plot(xpoints,ypoints,'-')
plt.show()

# %%
ypoints =np.array([3,8,1,12,7,9])

plt.plot(ypoints,marker='*')
plt.show()

# %%
plt.plot(ypoints,marker='X')

# %%
plt.plot(ypoints,marker='.')

# %%
plt.plot(ypoints,marker='_')

# %%
plt.plot(ypoints,marker='>')

# %%
yp=np.array([3,8,1,10])

plt.plot(ypoints, '*'':r')
plt.show()

# %%
yp = np.array([3,8,1,10])
xp = np.array([5,6,7,9])
plt.plot(xp,yp,marker = 'p',ms =10, color='green')   ###ms=markersize
plt.show()

# %%
yp = np.array([3,8,1,10])
xp = np.array([5,6,7,9])
plt.plot(xp,yp,marker = 'o',ms =20, mec='r')   ### mec=marker edge color 
plt.show()

# %%
yp = np.array([3,8,1,10])

plt.plot(xp,yp,marker = 'o',ms =20, mfc ='y',mec='k')   ### mfc=marker facee color 
plt.show()

# %%
yp = np.array([3,8,1,10])

plt.plot(yp, linestyle ='dashed',marker='o',mec='blue',ms=20,mfc='hotpink')
plt.show()

# %%
yp = np.array([3,8,1,10])

plt.plot(yp, linestyle ='dotted',marker='o',mec='blue',ms=20,mfc='green')
plt.show()

# %%
yp = np.array([3,8,1,10])

plt.plot(yp, linestyle ='dashed',marker='o',mec='blue',ms=20,mfc='hotpink',linewidth='10')
plt.show()

# %%
yp = np.array([3,8,1,10])

plt.plot(yp, linestyle ='dotted',marker='o',mec='blue',ms=20,mfc='hotpink',linewidth='5')
plt.show()

# %%
y1=np.array([3,8,1,10])
y2=np.array([6,2,5,11])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x=np.array([3,8,1,10])
y=np.array([6,2,5,11])
plt.title("sports data",loc='right',fontsize=20,color="red")
plt.xlabel("avg pulse",loc="left")
plt.ylabel("calorie burnage")

plt.plot(x,y)
plt.show()

# %%
x=np.array([3,8,1,10])
y=np.array([6,2,5,11])
plt.title("sports data",loc='right',fontsize=20,color="red")
plt.xlabel("avg pulse",loc="left")
plt.ylabel("calorie burnage")

plt.plot(x,y)

plt.grid()
plt.show()

# %%
x=np.array([3,8,1,10])
y=np.array([6,2,5,11])
plt.title("sports data",loc='right',fontsize=20,color="red")
plt.xlabel("avg pulse",loc="left")
plt.ylabel("calorie burnage")

plt.plot(x,y)

plt.grid(axis='x')
plt.show()

# %%
x=np.array([3,8,1,10])
y=np.array([6,2,5,11])
plt.title("sports data",loc='right',fontsize=20,color="red")
plt.xlabel("avg pulse",loc="left")
plt.ylabel("calorie burnage")

plt.plot(x,y)

plt.grid(color='green',linestyle='dotted')
plt.show()

# %%
#1

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("x")
plt.xlabel("XX")

y=np.array([10,20,30,40])
x=np.array([0,1,2,3])

plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("y")
plt.ylabel("YY")
 
plt.show()

#2
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.title("x")
plt.xlabel("XX")

y=np.array([10,20,30,40])
x=np.array([0,1,2,3])

plt.subplot(2,3,2)
plt.plot(x,y)
plt.title("y")
plt.ylabel("YY")
 
plt.show()

         
#3
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.title("x")
plt.xlabel("XX")

y=np.array([10,20,30,40])
x=np.array([0,1,2,3])

plt.subplot(2,3,3)
plt.plot(x,y)
plt.title("y")
plt.ylabel("YY")
 
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,10,15,20,25])
plt.scatter(x,y)

# %%
x=np.array([1,2])
y=np.array([5,10])
plt.plot(x,y)
plt.title("Relation b/w x & y",loc='left',color='blue')
plt.grid(color='r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
